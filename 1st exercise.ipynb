# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('Marks.csv')
df
# Out:
#   Stud  T1  T2  T3    T4    T5
# 0   x1  65  30  34  12.0  23.0
# 1   x2  85  40  24  65.0  98.0
# 2   x3  75  50  54  45.0   NaN
# 3   x4  55  30  65   NaN  43.0
# 4   x5  90  70  32  34.0  23.0

# %%
df.drop('Stud',axis=1,inplace=True)
df
# Out:
#    T1  T2  T3    T4    T5
# 0  65  30  34  12.0  23.0
# 1  85  40  24  65.0  98.0
# 2  75  50  54  45.0   NaN
# 3  55  30  65   NaN  43.0
# 4  90  70  32  34.0  23.0

# %%
df = df.apply(lambda row: row.fillna(row.mean()), axis=1)

# %%
df
# Out:
#      T1    T2    T3     T4    T5
# 0  65.0  30.0  34.0  12.00  23.0
# 1  85.0  40.0  24.0  65.00  98.0
# 2  75.0  50.0  54.0  45.00  56.0
# 3  55.0  30.0  65.0  48.25  43.0
# 4  90.0  70.0  32.0  34.00  23.0

# %%
df=pd.read_csv('ProductDiscount.csv')
df
# Out:
#     ProductCategory       Price  Quantity PurchaseDate  Discount
# 0             Books   25.244412       6.0   23/06/2022     False
# 1       Electronics  109.657164       3.0   30/10/2021     False
# 2             Books   87.975397       7.0   09/07/2020     False
# 3             Books  196.651937       NaN   08/12/2021     False
# 4       Electronics   31.287391       9.0   24/11/2022     False
# ..              ...         ...       ...          ...       ...
# 995        Clothing  186.813091       9.0   02/06/2020     False
# 996        Clothing   32.109616       5.0   13/07/2021     False
# 997           Books  165.315445       1.0   16/12/2020     False
# 998           Books  164.636852       5.0   14/12/2020      True
# 999     Electronics  176.815121       8.0   30/06/2020     False
#
# [1000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ProductCategory  1000 non-null   object
#  1   Price            950 non-null    float64
#  2   Quantity         900 non-null    float64
#  3   PurchaseDate     1000 non-null   object
#  4   Discount         1000 non-null   bool
# dtypes: bool(1), float64(2), object(2)
# memory usage: 32.4+ KB

# %%
df.isnull().sum()
# Out:
# ProductCategory      0
# Price               50
# Quantity           100
# PurchaseDate         0
# Discount             0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# ProductCategory    0
# Price              0
# Quantity           0
# PurchaseDate       0
# Discount           0
# dtype: int64

# %%
df.describe()
# Out:
#             Price    Quantity
# count  854.000000  854.000000
# mean   110.644510    4.973068
# std     65.310024    2.542114
# min     10.880084    1.000000
# 25%     56.350310    3.000000
# 50%    111.057101    5.000000
# 75%    155.656286    7.000000
# max    398.064973    9.000000

# %%
cat_col = [col for col in df.columns if df[col].dtype == 'object']
print('Categorical columns :',cat_col)
# Numerical columns
num_col = [col for col in df.columns if df[col].dtype != 'object']
print('Numerical columns :',num_col)
# Out:
# Categorical columns : ['ProductCategory', 'PurchaseDate']
# Numerical columns : ['Price', 'Quantity', 'Discount']

# %%
df[cat_col].nunique()
# Out:
# ProductCategory      3
# PurchaseDate       606
# dtype: int64

# %%
for col in df.columns:
    print(col," ",df[col].unique())
# Out:
# ProductCategory   ['Books' 'Electronics' 'Clothing']
# Price   [ 25.24441168 109.657164    87.97539713  31.28739141  85.59256382
#  194.1993823  174.4463539   59.00153714  42.4686416  186.5814379
#  115.7849497  118.606411   156.2036573   45.53831223  71.49905492
#   90.83292334 106.445972    56.05784916 126.0178081   64.83980512
#  120.4352621   39.3289159  101.4166194  111.1919922   19.846472
#   73.95481286  35.53878862  71.24723055 163.8761447   58.38172441
#  139.4855172  154.4432934  123.1713607   88.24977369  76.28497064
#  186.6105374  167.8176875  193.355113    33.61647246 148.8648203
#  376.5693736   44.43428257  22.6342908  150.8129234  119.1498915
#  169.9474676   36.55675156 161.1007893   48.30919081  41.09462914
#   41.21050161 164.7691968  136.3874719  218.7648614   78.17779198
#   84.56457041 165.1538935   93.43563263  81.61944159  67.26179609
#  152.0457822   54.12041208 180.9191689   82.93933206 113.2750436
# ...

# %%
df['PurchaseDate'].unique()[:25]
# Out:
# array(['23/06/2022', '30/10/2021', '09/07/2020', '24/11/2022',
#        '13/01/2021', '21/01/2021', '24/08/2020', '09/10/2020',
#        '01/01/2020', '24/08/2022', '20/06/2020', '22/04/2022',
#        '28/07/2021', '13/06/2020', '17/01/2021', '27/07/2020',
#        '11/08/2020', '03/01/2020', '02/09/2021', '25/04/2020',
#        '22/03/2021', '18/02/2021', '10/06/2022', '13/11/2022',
#        '24/10/2021'], dtype=object)

# %%
df.drop('PurchaseDate',axis=1,inplace = True)

# %%
df.head()
# Out:
#   ProductCategory       Price  Quantity  Discount
# 0           Books   25.244412       6.0     False
# 1     Electronics  109.657164       3.0     False
# 2           Books   87.975397       7.0     False
# 4     Electronics   31.287391       9.0     False
# 5     Electronics   85.592564       5.0     False

# %%
import matplotlib.pyplot as plt
 
plt.boxplot(df['Price'], vert=False)
plt.ylabel('Variable')
plt.xlabel('Price')
plt.title('Box Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
 
plt.boxplot(df1['Quantity'], vert=False)
plt.ylabel('Variable')
plt.xlabel('Quantity')
plt.title('Box Plot')
plt.show()

# %%
# calculate summary statistics
mean = df['Price'].mean()
std  = df['Price'].std()
 
# Calculate the lower and upper bounds
lower_bound = mean - std*2
upper_bound = mean + std*2
 
print('Lower Bound :',lower_bound)
print('Upper Bound :',upper_bound)
 
# Drop the outliers
df1 = df[(df['Price'] >= lower_bound) 
                & (df['Price'] <= upper_bound)]
# Out:
# Lower Bound : -19.975539120969017
# Upper Bound : 241.2645587523976

# %%
from sklearn.preprocessing import MinMaxScaler
x = df1[['Price','Quantity']]
# initialising the MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
num_col_ = [col for col in x.columns if x[col].dtype != 'object']
x1=x
# learning the statistical parameters for each of the data and transforming
x1[num_col_] = scaler.fit_transform(x1[num_col_])
x1.head()
# Out:
# C:\Users\shikh\AppData\Local\Temp\ipykernel_21004\3514741903.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x1[num_col_] = scaler.fit_transform(x1[num_col_])
#       Price  Quantity
# 0  0.063902     0.625
# 1  0.439428     0.250
# 2  0.342973     0.750
# 4  0.090786     1.000
# 5  0.332372     0.500
